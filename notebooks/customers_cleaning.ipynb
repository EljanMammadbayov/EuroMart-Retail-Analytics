# %%
import pandas as pd

# %%
df_customers = pd.read_csv(r'C:/Users/Eljan Mammadbayov/OneDrive/Рабочий стол/Python Practice/Euromart Claude/raw/customers.csv')

df_customers
# Out:
#      customer_id first_name  last_name      country              city  \
# 0      CUST_1001    Gabriel      Simon       France         Marseille
# 1      CUST_1002     Hannah  Schneider      Germany            Berlin
# 2      CUST_1003      Jules     Martin       France             Lille
# 3      CUST_1004      Jules     Michel       France         Marseille
# 4      CUST_1005       Emma    Mertens   Luxembourg   Luxembourg City
# ...          ...        ...        ...          ...               ...
# 1215   CUST_2216        Mia    Fischer      Germany            Berlin
# 1216   CUST_2217       Daan     Visser  Netherlands           Utrecht
# 1217   CUST_2218      Louis     Martin       France              Nice
# 1218   CUST_2219      Marie     Dubois   Luxembourg  Esch-sur-Alzette
# 1219   CUST_2220      Alice     Dubois       France         Marseille
#
#                         email signup_date loyalty_status   age
# 0     gabriel.simon@gmail.com   10/5/2022         Silver  55.0
# 1                         NaN   1/13/2025           Gold  70.0
# 2      jules.martin@yahoo.com    9/8/2022            NaN  65.0
# 3     jules.michel@icloud.com  10/19/2024            NaN  34.0
# 4      emma.mertens@yahoo.com    9/2/2024            NaN  51.0
# ...                       ...         ...            ...   ...
# 1215   mia.fischer@icloud.com    8/7/2023         Silver  30.0
# 1216    daan.visser@yahoo.com   5/18/2024       Platinum  48.0
# 1217   louis.martin@gmail.com   4/10/2024       Platinum   NaN
# 1218   marie.dubois@yahoo.com         NaN         Silver  52.0
# 1219   alice.dubois@gmail.com    5/2/2022         Silver  58.0
#
# [1220 rows x 9 columns]

# %%
df_customers.isnull().sum()
# Out:
# customer_id         0
# first_name          0
# last_name           0
# country             0
# city                0
# email              41
# signup_date        50
# loyalty_status    524
# age                43
# dtype: int64

# %%
#Cleaning will be based on data profiling performed on SQL. Issues have already been noted.
#1 First, I will fix malformed emails (emails missing @ and emails in caps)

# %%
def fix_email_format(email):
    """Fix common email issues"""
    if pd.isna(email):
        return None
    
    email = str(email).strip()
    
    # Fix missing @ symbol (e.g., "namegmail.com" → "name@gmail.com")
    if '@' not in email and '.' in email:
        # Find common domains
        domains = ['gmail.com', 'outlook.com', 'yahoo.com', 'hotmail.com', 'icloud.com']
        for domain in domains:
            if domain in email.lower():
                email = email.lower().replace(domain, f'@{domain}')
                break
    
    # Standardize to lowercase
    email = email.lower()

    # Basic validation
    # Confirming that email domain has the right structure (gmail.com, yahoo.com). If not, return none
    if '@' in email and '.' in email.split('@')[1]:
        return email
    else:
        return None  # Invalid email

# Apply fix
df_customers['email_original'] = df_customers['email']  # Backup
df_customers['email'] = df_customers['email'].apply(fix_email_format)

# %%
df_customers[['email']].head(25)
# Out:
#                            email
# 0        gabriel.simon@gmail.com
# 1                           None
# 2         jules.martin@yahoo.com
# 3        jules.michel@icloud.com
# 4         emma.mertens@yahoo.com
# 5          anna.visser@gmail.com
# 6        sophie.jansen@gmail.com
# 7   lucas.vandenberg@outlook.com
# 8        liam.visser@hotmail.com
# 9      gabriel.michel@icloud.com
# 10         leon.wagner@yahoo.com
# 11       noah.devries@icloud.com
# 12         mia.weber@hotmail.com
# 13       arthur.martin@yahoo.com
# 14         lars.martin@yahoo.com
# 15          paul.weber@gmail.com
# 16        daan.devries@yahoo.com
# 17      lars.janssens@icloud.com
# 18       noah.peeters@icloud.com
# 19       gabriel.simon@gmail.com
# 20      arthur.mertens@gmail.com
# 21        sofie.maes@hotmail.com
# 22         mia.meyer@outlook.com
# 23        finn.wagner@icloud.com
# 24    finn.schneider@hotmail.com

# %%
#2 Second, merging customers with duplicate emails and keeping their earliest sign up data.

# Step 1: Identify duplicates by email
duplicate_emails = df_customers[df_customers['email'].notna()].groupby('email').filter(lambda x: len(x) > 1)

print(f"Found {len(duplicate_emails)} customer records with duplicate emails")
print(f"Affecting {duplicate_emails['email'].nunique()} unique email addresses")

# Step 2: For each duplicate email, keep the earliest customer
def merge_duplicate_customers(df):
    """
    For duplicate emails:
    1. Keep the customer with earliest signup_date
    2. Create mapping table for order reassignment
    3. Remove duplicate customer records
    """
    
    # Create mapping: duplicate_id → primary_id
    customer_mapping = {}
    
    # Group by email
    for email, group in df.groupby('email'):
        if len(group) > 1 and pd.notna(email):
            # Sort by signup_date (earliest first), then by customer_id
            sorted_group = group.sort_values(['signup_date', 'customer_id'], na_position='last')
            
            primary_id = sorted_group.iloc[0]['customer_id']
            duplicate_ids = sorted_group.iloc[1:]['customer_id'].tolist()
            
            # Map duplicates to primary
            for dup_id in duplicate_ids:
                customer_mapping[dup_id] = primary_id
            
            print(f"Email: {email}")
            print(f"  Primary: {primary_id}")
            print(f"  Duplicates: {duplicate_ids}")
    
    # Keep only primary customers (remove duplicates)
    customers_to_remove = list(customer_mapping.keys())
    df_clean = df[~df['customer_id'].isin(customers_to_remove)].copy()
    
    print(f"\n✓ Removed {len(customers_to_remove)} duplicate customers")
    print(f"✓ Kept {len(df_clean)} unique customers")
    
    return df_clean, customer_mapping

df_customers_clean, customer_id_mapping = merge_duplicate_customers(df_customers)

# Save mapping for later (to update orders table)
pd.DataFrame(list(customer_id_mapping.items()), 
             columns=['old_customer_id', 'new_customer_id']).to_csv('C:/Users/Eljan Mammadbayov/OneDrive/Рабочий стол/Python Practice/Euromart Claude/customer_id_mapping.csv', index=False)
# Out:
# Found 750 customer records with duplicate emails
# Affecting 313 unique email addresses
# Email: alice.bernard@yahoo.com
#   Primary: CUST_1439
#   Duplicates: ['CUST_2137']
# Email: alice.dubois@gmail.com
#   Primary: CUST_1715
#   Duplicates: ['CUST_2220', 'CUST_1646', 'CUST_1837']
# Email: alice.laurent@hotmail.com
#   Primary: CUST_1280
#   Duplicates: ['CUST_1775']
# Email: alice.lefebvre@gmail.com
#   Primary: CUST_1661
#   Duplicates: ['CUST_1989', 'CUST_1474']
# Email: alice.lefebvre@outlook.com
#   Primary: CUST_1791
#   Duplicates: ['CUST_1379', 'CUST_1321', 'CUST_1391']
# Email: alice.lefebvre@yahoo.com
#   Primary: CUST_1575
#   Duplicates: ['CUST_2167', 'CUST_2180', 'CUST_2129']
# Email: alice.martin@hotmail.com
#   Primary: CUST_1882
#   Duplicates: ['CUST_2131', 'CUST_2061']
# Email: alice.martin@icloud.com
#   Primary: CUST_1347
#   Duplicates: ['CUST_1078', 'CUST_1042']
# Email: alice.martin@yahoo.com
#   Primary: CUST_1477
#   Duplicates: ['CUST_1116']
# Email: anna.bakker@outlook.com
#   Primary: CUST_1718
#   Duplicates: ['CUST_1193']
# Email: anna.devries@yahoo.com
#   Primary: CUST_1563
#   Duplicates: ['CUST_1145']
# Email: anna.visser@gmail.com
#   Primary: CUST_1852
#   Duplicates: ['CUST_1571', 'CUST_1620', 'CUST_1006']
# Email: anna.visser@icloud.com
#   Primary: CUST_1045
#   Duplicates: ['CUST_1946']
# Email: anna.visser@outlook.com
#   Primary: CUST_1678
#   Duplicates: ['CUST_2005']
# Email: arthur.bernard@hotmail.com
#   Primary: CUST_1708
#   Duplicates: ['CUST_2202']
# Email: arthur.bernard@icloud.com
#   Primary: CUST_2066
#   Duplicates: ['CUST_2069', 'CUST_1809']
# Email: arthur.dubois@gmail.com
#   Primary: CUST_1290
#   Duplicates: ['CUST_1282', 'CUST_1680', 'CUST_1505', 'CUST_2177', 'CUST_1432']
# Email: arthur.laurent@gmail.com
#   Primary: CUST_1517
#   Duplicates: ['CUST_1407']
# Email: arthur.laurent@yahoo.com
#   Primary: CUST_1051
#   Duplicates: ['CUST_1823']
# Email: arthur.lefebvre@yahoo.com
#   Primary: CUST_2051
#   Duplicates: ['CUST_1127']
# Email: arthur.martin@outlook.com
#   Primary: CUST_1048
#   Duplicates: ['CUST_1318']
# Email: arthur.martin@yahoo.com
#   Primary: CUST_1340
#   Duplicates: ['CUST_1014']
# Email: arthur.michel@gmail.com
#   Primary: CUST_1936
#   Duplicates: ['CUST_2030']
# Email: arthur.michel@hotmail.com
#   Primary: CUST_1291
#   Duplicates: ['CUST_1957', 'CUST_1195']
# Email: ben.meyer@icloud.com
#   Primary: CUST_1143
#   Duplicates: ['CUST_1117']
# Email: ben.meyer@outlook.com
#   Primary: CUST_2073
#   Duplicates: ['CUST_1205']
# Email: ben.müller@gmail.com
#   Primary: CUST_1489
#   Duplicates: ['CUST_1310']
# Email: ben.müller@outlook.com
#   Primary: CUST_1494
#   Duplicates: ['CUST_1027', 'CUST_1138', 'CUST_1698']
# Email: ben.schneider@hotmail.com
#   Primary: CUST_1168
#   Duplicates: ['CUST_1962']
# Email: ben.schneider@outlook.com
#   Primary: CUST_1266
#   Duplicates: ['CUST_1161']
# Email: ben.schneider@yahoo.com
#   Primary: CUST_2015
#   Duplicates: ['CUST_2081']
# Email: chloé.dubois@icloud.com
#   Primary: CUST_1194
#   Duplicates: ['CUST_2011']
# Email: chloé.janssens@hotmail.com
#   Primary: CUST_2044
#   Duplicates: ['CUST_1979']
# Email: chloé.janssens@yahoo.com
#   Primary: CUST_1254
#   Duplicates: ['CUST_1881']
# Email: chloé.laurent@gmail.com
#   Primary: CUST_1429
#   Duplicates: ['CUST_2116', 'CUST_1770']
# Email: chloé.laurent@icloud.com
#   Primary: CUST_1294
#   Duplicates: ['CUST_1884']
# Email: chloé.lefebvre@outlook.com
#   Primary: CUST_2065
#   Duplicates: ['CUST_1479', 'CUST_1058']
# Email: chloé.lefebvre@yahoo.com
#   Primary: CUST_1102
#   Duplicates: ['CUST_1140']
# Email: chloé.martin@hotmail.com
#   Primary: CUST_1465
#   Duplicates: ['CUST_1174', 'CUST_1460']
# Email: chloé.michel@gmail.com
#   Primary: CUST_1841
#   Duplicates: ['CUST_1043', 'CUST_1072']
# Email: chloé.michel@hotmail.com
#   Primary: CUST_1819
#   Duplicates: ['CUST_1677']
# Email: chloé.michel@outlook.com
#   Primary: CUST_2009
#   Duplicates: ['CUST_1157', 'CUST_1787', 'CUST_1993', 'CUST_1396', 'CUST_1413']
# Email: chloé.simon@hotmail.com
#   Primary: CUST_1386
#   Duplicates: ['CUST_1074']
# Email: daan.bakker@icloud.com
#   Primary: CUST_1354
#   Duplicates: ['CUST_1216', 'CUST_2119']
# Email: daan.bakker@outlook.com
#   Primary: CUST_2101
#   Duplicates: ['CUST_2215']
# Email: daan.dejong@icloud.com
#   Primary: CUST_1232
#   Duplicates: ['CUST_1317', 'CUST_2204']
# Email: daan.jansen@gmail.com
#   Primary: CUST_1702
#   Duplicates: ['CUST_1466']
# Email: daan.vandenberg@yahoo.com
#   Primary: CUST_1463
#   Duplicates: ['CUST_1285', 'CUST_1710']
# Email: daan.visser@yahoo.com
#   Primary: CUST_1639
#   Duplicates: ['CUST_2217']
# Email: emma.bakker@outlook.com
#   Primary: CUST_2086
#   Duplicates: ['CUST_1361']
# Email: emma.bernard@gmail.com
#   Primary: CUST_1425
#   Duplicates: ['CUST_1868', 'CUST_1177']
# Email: emma.bernard@yahoo.com
#   Primary: CUST_1265
#   Duplicates: ['CUST_1910']
# Email: emma.dejong@hotmail.com
#   Primary: CUST_2185
#   Duplicates: ['CUST_1529', 'CUST_1385']
# Email: emma.dejong@icloud.com
#   Primary: CUST_1271
#   Duplicates: ['CUST_2174']
# Email: emma.dejong@outlook.com
#   Primary: CUST_1180
#   Duplicates: ['CUST_1830']
# Email: emma.dejong@yahoo.com
#   Primary: CUST_1431
#   Duplicates: ['CUST_1037', 'CUST_1302']
# Email: emma.desmet@hotmail.com
#   Primary: CUST_1812
#   Duplicates: ['CUST_1747']
# Email: emma.desmet@outlook.com
#   Primary: CUST_2176
#   Duplicates: ['CUST_2206', 'CUST_1686']
# Email: emma.desmet@yahoo.com
#   Primary: CUST_2068
#   Duplicates: ['CUST_1421']
# Email: emma.devries@hotmail.com
#   Primary: CUST_1284
#   Duplicates: ['CUST_1777']
# Email: emma.devries@icloud.com
#   Primary: CUST_2017
#   Duplicates: ['CUST_1875', 'CUST_1624', 'CUST_1803']
# Email: emma.dubois@hotmail.com
#   Primary: CUST_1614
#   Duplicates: ['CUST_2186']
# Email: emma.dubois@icloud.com
#   Primary: CUST_1619
#   Duplicates: ['CUST_1730']
# Email: emma.dubois@yahoo.com
#   Primary: CUST_1859
#   Duplicates: ['CUST_1504']
# Email: emma.fischer@yahoo.com
#   Primary: CUST_1598
#   Duplicates: ['CUST_1594']
# Email: emma.jacobs@gmail.com
#   Primary: CUST_1186
#   Duplicates: ['CUST_1906']
# Email: emma.jacobs@hotmail.com
#   Primary: CUST_1550
#   Duplicates: ['CUST_2016', 'CUST_1134']
# Email: emma.jacobs@icloud.com
#   Primary: CUST_1671
#   Duplicates: ['CUST_1166']
# Email: emma.jansen@icloud.com
#   Primary: CUST_2014
#   Duplicates: ['CUST_2037', 'CUST_1763']
# Email: emma.jansen@outlook.com
#   Primary: CUST_1123
#   Duplicates: ['CUST_1416']
# Email: emma.janssens@hotmail.com
#   Primary: CUST_1189
#   Duplicates: ['CUST_1461']
# Email: emma.janssens@outlook.com
#   Primary: CUST_1107
#   Duplicates: ['CUST_1343', 'CUST_1516', 'CUST_1333']
# Email: emma.laurent@gmail.com
#   Primary: CUST_1276
#   Duplicates: ['CUST_2149']
# Email: emma.laurent@hotmail.com
#   Primary: CUST_1362
#   Duplicates: ['CUST_2000']
# Email: emma.laurent@yahoo.com
#   Primary: CUST_1056
#   Duplicates: ['CUST_1249', 'CUST_1684']
# Email: emma.lefebvre@hotmail.com
#   Primary: CUST_1197
#   Duplicates: ['CUST_1114', 'CUST_1797']
# Email: emma.maes@gmail.com
#   Primary: CUST_1586
#   Duplicates: ['CUST_1184', 'CUST_1374', 'CUST_1345']
# Email: emma.maes@hotmail.com
#   Primary: CUST_1531
#   Duplicates: ['CUST_1573', 'CUST_1591']
# Email: emma.maes@outlook.com
#   Primary: CUST_1270
#   Duplicates: ['CUST_1799']
# Email: emma.maes@yahoo.com
#   Primary: CUST_2115
#   Duplicates: ['CUST_1992']
# Email: emma.martin@gmail.com
#   Primary: CUST_1896
#   Duplicates: ['CUST_1916', 'CUST_1628', 'CUST_1553', 'CUST_1526']
# Email: emma.martin@hotmail.com
#   Primary: CUST_1510
#   Duplicates: ['CUST_1108', 'CUST_1467']
# Email: emma.mertens@outlook.com
#   Primary: CUST_1411
#   Duplicates: ['CUST_1245']
# Email: emma.mertens@yahoo.com
#   Primary: CUST_1781
#   Duplicates: ['CUST_1005', 'CUST_2175']
# Email: emma.meyer@gmail.com
#   Primary: CUST_1224
#   Duplicates: ['CUST_1393']
# Email: emma.michel@hotmail.com
#   Primary: CUST_1607
#   Duplicates: ['CUST_1894']
# Email: emma.müller@yahoo.com
#   Primary: CUST_1643
#   Duplicates: ['CUST_1200']
# Email: emma.peeters@outlook.com
#   Primary: CUST_1970
#   Duplicates: ['CUST_1451']
# Email: emma.peeters@yahoo.com
#   Primary: CUST_1052
#   Duplicates: ['CUST_1484']
# Email: emma.schmidt@gmail.com
#   Primary: CUST_1754
#   Duplicates: ['CUST_1612', 'CUST_1081']
# Email: emma.schmidt@hotmail.com
#   Primary: CUST_1952
#   Duplicates: ['CUST_2198']
# Email: emma.schmidt@icloud.com
#   Primary: CUST_2034
#   Duplicates: ['CUST_1088', 'CUST_1230']
# Email: emma.vandenberg@gmail.com
#   Primary: CUST_1422
#   Duplicates: ['CUST_1725']
# Email: emma.vandenberg@outlook.com
#   Primary: CUST_1250
#   Duplicates: ['CUST_1487']
# Email: emma.visser@hotmail.com
#   Primary: CUST_1373
#   Duplicates: ['CUST_1865', 'CUST_1966']
# Email: emma.wagner@gmail.com
#   Primary: CUST_2001
#   Duplicates: ['CUST_2146', 'CUST_1094']
# Email: emma.weber@icloud.com
#   Primary: CUST_1804
#   Duplicates: ['CUST_1814', 'CUST_1380']
# Email: emma.willems@gmail.com
#   Primary: CUST_1443
#   Duplicates: ['CUST_1564']
# Email: emma.willems@icloud.com
#   Primary: CUST_1470
#   Duplicates: ['CUST_1581']
# Email: emma.willems@yahoo.com
#   Primary: CUST_1512
#   Duplicates: ['CUST_1899']
# Email: finn.fischer@gmail.com
#   Primary: CUST_1300
#   Duplicates: ['CUST_1344']
# Email: finn.fischer@outlook.com
#   Primary: CUST_1935
#   Duplicates: ['CUST_1049']
# Email: finn.meyer@gmail.com
#   Primary: CUST_1772
#   Duplicates: ['CUST_1828']
# Email: finn.meyer@icloud.com
#   Primary: CUST_1476
#   Duplicates: ['CUST_1736']
# Email: finn.schneider@hotmail.com
#   Primary: CUST_1025
#   Duplicates: ['CUST_1801']
# Email: finn.schneider@outlook.com
#   Primary: CUST_1231
#   Duplicates: ['CUST_1918']
# Email: finn.wagner@icloud.com
#   Primary: CUST_1191
#   Duplicates: ['CUST_1024', 'CUST_1972']
# Email: finn.wagner@outlook.com
#   Primary: CUST_1146
#   Duplicates: ['CUST_2075']
# Email: finn.wagner@yahoo.com
#   Primary: CUST_1428
#   Duplicates: ['CUST_1766', 'CUST_2128']
# Email: finn.weber@yahoo.com
#   Primary: CUST_1913
#   Duplicates: ['CUST_1780']
# Email: gabriel.bernard@gmail.com
#   Primary: CUST_1660
#   Duplicates: ['CUST_1228']
# Email: gabriel.bernard@hotmail.com
#   Primary: CUST_2093
#   Duplicates: ['CUST_2114']
# Email: gabriel.bernard@yahoo.com
#   Primary: CUST_1144
#   Duplicates: ['CUST_1106']
# Email: gabriel.janssens@yahoo.com
#   Primary: CUST_1872
#   Duplicates: ['CUST_1973']
# Email: gabriel.laurent@icloud.com
#   Primary: CUST_2007
#   Duplicates: ['CUST_1355']
# Email: gabriel.laurent@outlook.com
#   Primary: CUST_1226
#   Duplicates: ['CUST_1750', 'CUST_1951']
# Email: gabriel.lefebvre@gmail.com
#   Primary: CUST_1452
#   Duplicates: ['CUST_1920']
# Email: gabriel.lefebvre@hotmail.com
#   Primary: CUST_1790
#   Duplicates: ['CUST_1945', 'CUST_2098']
# Email: gabriel.lefebvre@outlook.com
#   Primary: CUST_1792
#   Duplicates: ['CUST_1854']
# Email: gabriel.lefebvre@yahoo.com
#   Primary: CUST_2164
#   Duplicates: ['CUST_1518', 'CUST_1331']
# Email: gabriel.martin@hotmail.com
#   Primary: CUST_1312
#   Duplicates: ['CUST_1308']
# Email: gabriel.martin@icloud.com
#   Primary: CUST_2144
#   Duplicates: ['CUST_1118', 'CUST_1561']
# Email: gabriel.michel@gmail.com
#   Primary: CUST_1076
#   Duplicates: ['CUST_1236']
# Email: gabriel.michel@icloud.com
#   Primary: CUST_1010
#   Duplicates: ['CUST_1547']
# Email: gabriel.simon@gmail.com
#   Primary: CUST_1001
#   Duplicates: ['CUST_1020', 'CUST_2027']
# Email: gabriel.simon@outlook.com
#   Primary: CUST_1328
#   Duplicates: ['CUST_1100']
# Email: gabriel.simon@yahoo.com
#   Primary: CUST_1507
#   Duplicates: ['CUST_1329']
# Email: hannah.schmidt@icloud.com
#   Primary: CUST_1653
#   Duplicates: ['CUST_1488']
# Email: hannah.schneider@hotmail.com
#   Primary: CUST_1593
#   Duplicates: ['CUST_1933', 'CUST_1406']
# Email: hannah.schneider@outlook.com
#   Primary: CUST_1408
#   Duplicates: ['CUST_1893']
# Email: hannah.wagner@yahoo.com
#   Primary: CUST_2090
#   Duplicates: ['CUST_1169']
# Email: hannah.weber@hotmail.com
#   Primary: CUST_1297
#   Duplicates: ['CUST_1783']
# Email: hannah.weber@outlook.com
#   Primary: CUST_1046
#   Duplicates: ['CUST_2094']
# Email: jules.bernard@hotmail.com
#   Primary: CUST_2099
#   Duplicates: ['CUST_1932']
# Email: jules.bernard@icloud.com
#   Primary: CUST_1696
#   Duplicates: ['CUST_2053']
# Email: jules.bernard@yahoo.com
#   Primary: CUST_2192
#   Duplicates: ['CUST_1930']
# Email: jules.desmet@hotmail.com
#   Primary: CUST_1706
#   Duplicates: ['CUST_1562']
# Email: jules.dubois@outlook.com
#   Primary: CUST_2189
#   Duplicates: ['CUST_1390']
# Email: jules.laurent@hotmail.com
#   Primary: CUST_1498
#   Duplicates: ['CUST_1765']
# Email: jules.laurent@outlook.com
#   Primary: CUST_1181
#   Duplicates: ['CUST_1815']
# Email: jules.lefebvre@icloud.com
#   Primary: CUST_1330
#   Duplicates: ['CUST_1890']
# Email: jules.michel@icloud.com
#   Primary: CUST_1004
#   Duplicates: ['CUST_1306']
# Email: jules.simon@gmail.com
#   Primary: CUST_1288
#   Duplicates: ['CUST_2033']
# Email: jules.simon@hotmail.com
#   Primary: CUST_1670
#   Duplicates: ['CUST_1767', 'CUST_2205']
# Email: julia.bakker@icloud.com
#   Primary: CUST_1316
#   Duplicates: ['CUST_1336']
# Email: julia.jansen@gmail.com
#   Primary: CUST_1551
#   Duplicates: ['CUST_1030']
# Email: julia.jansen@icloud.com
#   Primary: CUST_1542
#   Duplicates: ['CUST_1348']
# Email: julia.jansen@outlook.com
#   Primary: CUST_1263
#   Duplicates: ['CUST_2002']
# Email: julia.vandenberg@gmail.com
#   Primary: CUST_1448
#   Duplicates: ['CUST_2201']
# Email: julia.vandenberg@hotmail.com
#   Primary: CUST_1286
#   Duplicates: ['CUST_1352']
# Email: julia.vandenberg@yahoo.com
#   Primary: CUST_1601
#   Duplicates: ['CUST_1877']
# Email: julia.visser@hotmail.com
#   Primary: CUST_1748
#   Duplicates: ['CUST_1125', 'CUST_1963']
# Email: lars.bernard@hotmail.com
#   Primary: CUST_1491
#   Duplicates: ['CUST_1275']
# Email: lars.desmet@gmail.com
#   Primary: CUST_1349
#   Duplicates: ['CUST_1545', 'CUST_1520']
# Email: lars.desmet@yahoo.com
#   Primary: CUST_1674
#   Duplicates: ['CUST_2148']
# Email: lars.jacobs@icloud.com
#   Primary: CUST_2157
#   Duplicates: ['CUST_1071']
# Email: lars.jacobs@yahoo.com
#   Primary: CUST_1237
#   Duplicates: ['CUST_1438']
# Email: lars.janssens@icloud.com
#   Primary: CUST_1252
#   Duplicates: ['CUST_1018', 'CUST_1260']
# Email: lars.janssens@outlook.com
#   Primary: CUST_1241
#   Duplicates: ['CUST_1050', 'CUST_1061']
# Email: lars.maes@gmail.com
#   Primary: CUST_2102
#   Duplicates: ['CUST_2045', 'CUST_1802']
# Email: lars.peeters@icloud.com
#   Primary: CUST_1309
#   Duplicates: ['CUST_1914']
# Email: lars.peeters@outlook.com
#   Primary: CUST_1857
#   Duplicates: ['CUST_1623']
# Email: lars.willems@gmail.com
#   Primary: CUST_1165
#   Duplicates: ['CUST_1824', 'CUST_1897']
# Email: leon.meyer@outlook.com
#   Primary: CUST_2038
#   Duplicates: ['CUST_1524']
# Email: leon.meyer@yahoo.com
#   Primary: CUST_1444
#   Duplicates: ['CUST_2042']
# Email: leon.müller@gmail.com
#   Primary: CUST_1688
#   Duplicates: ['CUST_1087']
# Email: leon.müller@icloud.com
#   Primary: CUST_1705
#   Duplicates: ['CUST_1273', 'CUST_1243', 'CUST_2067', 'CUST_2200']
# Email: leon.schmidt@hotmail.com
#   Primary: CUST_1990
#   Duplicates: ['CUST_1759']
# Email: leon.schmidt@icloud.com
#   Primary: CUST_1274
#   Duplicates: ['CUST_1299']
# Email: leon.weber@outlook.com
#   Primary: CUST_1784
#   Duplicates: ['CUST_2158']
# Email: liam.bakker@hotmail.com
#   Primary: CUST_1402
#   Duplicates: ['CUST_1744']
# Email: liam.bakker@yahoo.com
#   Primary: CUST_1418
#   Duplicates: ['CUST_1365']
# Email: liam.dejong@hotmail.com
#   Primary: CUST_1805
#   Duplicates: ['CUST_2012']
# Email: liam.dejong@icloud.com
#   Primary: CUST_1753
#   Duplicates: ['CUST_1538']
# Email: liam.dejong@yahoo.com
#   Primary: CUST_1401
#   Duplicates: ['CUST_2021', 'CUST_2155']
# Email: liam.devries@hotmail.com
#   Primary: CUST_1253
#   Duplicates: ['CUST_1692']
# Email: liam.devries@outlook.com
#   Primary: CUST_2127
#   Duplicates: ['CUST_1908']
# Email: liam.jansen@gmail.com
#   Primary: CUST_1363
#   Duplicates: ['CUST_2207', 'CUST_2072']
# Email: liam.jansen@yahoo.com
#   Primary: CUST_2112
#   Duplicates: ['CUST_1099']
# Email: liam.vandenberg@gmail.com
#   Primary: CUST_1126
#   Duplicates: ['CUST_1399']
# Email: liam.visser@yahoo.com
#   Primary: CUST_1713
#   Duplicates: ['CUST_1558']
# Email: louis.bernard@outlook.com
#   Primary: CUST_2120
#   Duplicates: ['CUST_1891', 'CUST_1536']
# Email: louis.jacobs@hotmail.com
#   Primary: CUST_1672
#   Duplicates: ['CUST_1389']
# Email: louis.janssens@yahoo.com
#   Primary: CUST_1080
#   Duplicates: ['CUST_2214']
# Email: louis.laurent@gmail.com
#   Primary: CUST_2117
#   Duplicates: ['CUST_2173']
# Email: louis.martin@gmail.com
#   Primary: CUST_1597
#   Duplicates: ['CUST_2218']
# Email: louis.martin@hotmail.com
#   Primary: CUST_1975
#   Duplicates: ['CUST_1502']
# Email: louis.michel@yahoo.com
#   Primary: CUST_2159
#   Duplicates: ['CUST_1816', 'CUST_1590']
# Email: louis.simon@gmail.com
#   Primary: CUST_1026
#   Duplicates: ['CUST_1034']
# Email: louis.simon@hotmail.com
#   Primary: CUST_2100
#   Duplicates: ['CUST_1219']
# Email: louis.simon@icloud.com
#   Primary: CUST_2199
#   Duplicates: ['CUST_2193']
# Email: louise.bernard@gmail.com
#   Primary: CUST_1761
#   Duplicates: ['CUST_1430', 'CUST_1492']
# Email: louise.bernard@hotmail.com
#   Primary: CUST_1153
#   Duplicates: ['CUST_2135']
# Email: louise.desmet@hotmail.com
#   Primary: CUST_1523
#   Duplicates: ['CUST_1456', 'CUST_1751', 'CUST_2040', 'CUST_2210']
# Email: louise.desmet@yahoo.com
#   Primary: CUST_1835
#   Duplicates: ['CUST_1921']
# Email: louise.dubois@gmail.com
#   Primary: CUST_1420
#   Duplicates: ['CUST_2182']
# Email: louise.dubois@icloud.com
#   Primary: CUST_1589
#   Duplicates: ['CUST_1844']
# Email: louise.jacobs@gmail.com
#   Primary: CUST_1839
#   Duplicates: ['CUST_1387', 'CUST_1588']
# Email: louise.jacobs@icloud.com
#   Primary: CUST_1442
#   Duplicates: ['CUST_1032', 'CUST_2041', 'CUST_1182', 'CUST_1486', 'CUST_2071']
# Email: louise.janssens@outlook.com
#   Primary: CUST_1904
#   Duplicates: ['CUST_1820']
# Email: louise.lefebvre@outlook.com
#   Primary: CUST_1849
#   Duplicates: ['CUST_1724']
# Email: louise.lefebvre@yahoo.com
#   Primary: CUST_2152
#   Duplicates: ['CUST_1539']
# Email: louise.maes@outlook.com
#   Primary: CUST_1417
#   Duplicates: ['CUST_1160', 'CUST_1101', 'CUST_2130']
# Email: louise.martin@hotmail.com
#   Primary: CUST_1154
#   Duplicates: ['CUST_1768']
# Email: louise.mertens@gmail.com
#   Primary: CUST_1086
#   Duplicates: ['CUST_1532']
# Email: louise.mertens@hotmail.com
#   Primary: CUST_2122
#   Duplicates: ['CUST_1543']
# Email: louise.mertens@icloud.com
#   Primary: CUST_2188
#   Duplicates: ['CUST_1173']
# Email: louise.mertens@outlook.com
#   Primary: CUST_1214
#   Duplicates: ['CUST_2080']
# Email: louise.michel@gmail.com
#   Primary: CUST_1188
#   Duplicates: ['CUST_2058']
# Email: louise.michel@outlook.com
#   Primary: CUST_1927
#   Duplicates: ['CUST_2145', 'CUST_2063']
# Email: louise.michel@yahoo.com
#   Primary: CUST_1697
#   Duplicates: ['CUST_1334', 'CUST_1515']
# Email: louise.peeters@hotmail.com
#   Primary: CUST_2082
#   Duplicates: ['CUST_1110', 'CUST_1834', 'CUST_1369']
# Email: louise.simon@yahoo.com
#   Primary: CUST_1650
#   Duplicates: ['CUST_2111', 'CUST_1583']
# Email: lucas.bakker@hotmail.com
#   Primary: CUST_2097
#   Duplicates: ['CUST_1211', 'CUST_1372']
# Email: lucas.desmet@hotmail.com
#   Primary: CUST_2088
#   Duplicates: ['CUST_1967', 'CUST_1649', 'CUST_1995']
# Email: lucas.devries@gmail.com
#   Primary: CUST_1167
#   Duplicates: ['CUST_1314']
# Email: lucas.devries@hotmail.com
#   Primary: CUST_1850
#   Duplicates: ['CUST_1621']
# Email: lucas.jacobs@yahoo.com
#   Primary: CUST_1592
#   Duplicates: ['CUST_2060']
# Email: lucas.janssens@icloud.com
#   Primary: CUST_1738
#   Duplicates: ['CUST_1178']
# Email: lucas.janssens@outlook.com
#   Primary: CUST_2169
#   Duplicates: ['CUST_1070']
# Email: lucas.maes@hotmail.com
#   Primary: CUST_1041
#   Duplicates: ['CUST_1035']
# Email: lucas.maes@icloud.com
#   Primary: CUST_1756
#   Duplicates: ['CUST_1843']
# Email: lucas.maes@outlook.com
#   Primary: CUST_1090
#   Duplicates: ['CUST_1554', 'CUST_1938']
# Email: lucas.maes@yahoo.com
#   Primary: CUST_1567
#   Duplicates: ['CUST_1728', 'CUST_1202']
# Email: lucas.peeters@gmail.com
#   Primary: CUST_1481
#   Duplicates: ['CUST_1240']
# Email: lucas.peeters@icloud.com
#   Primary: CUST_1341
#   Duplicates: ['CUST_1858']
# Email: lucas.peeters@outlook.com
#   Primary: CUST_1723
#   Duplicates: ['CUST_1608']
# Email: lucas.peeters@yahoo.com
#   Primary: CUST_1199
#   Duplicates: ['CUST_2203']
# Email: lucas.vandenberg@hotmail.com
#   Primary: CUST_1862
#   Duplicates: ['CUST_2161', 'CUST_1500']
# Email: lucas.vandenberg@outlook.com
#   Primary: CUST_1454
#   Duplicates: ['CUST_1008', 'CUST_2170']
# Email: lucas.visser@hotmail.com
#   Primary: CUST_1244
#   Duplicates: ['CUST_1149']
# Email: lucas.willems@outlook.com
#   Primary: CUST_1261
#   Duplicates: ['CUST_1605']
# Email: marie.desmet@hotmail.com
#   Primary: CUST_1513
#   Duplicates: ['CUST_1807', 'CUST_1097']
# Email: marie.desmet@outlook.com
#   Primary: CUST_1415
#   Duplicates: ['CUST_1234', 'CUST_1435', 'CUST_1810']
# Email: marie.dubois@hotmail.com
#   Primary: CUST_1209
#   Duplicates: ['CUST_1259']
# Email: marie.dubois@yahoo.com
#   Primary: CUST_1221
#   Duplicates: ['CUST_2219']
# Email: marie.jacobs@yahoo.com
#   Primary: CUST_2023
#   Duplicates: ['CUST_1641']
# Email: marie.janssens@hotmail.com
#   Primary: CUST_1307
#   Duplicates: ['CUST_1464']
# Email: marie.mertens@gmail.com
#   Primary: CUST_1251
#   Duplicates: ['CUST_2107']
# Email: marie.mertens@icloud.com
#   Primary: CUST_1449
#   Duplicates: ['CUST_1785']
# Email: marie.mertens@yahoo.com
#   Primary: CUST_1170
#   Duplicates: ['CUST_1940']
# Email: mia.fischer@icloud.com
#   Primary: CUST_1998
#   Duplicates: ['CUST_1247', 'CUST_2216']
# Email: mia.meyer@outlook.com
#   Primary: CUST_1584
#   Duplicates: ['CUST_1023']
# Email: mia.schneider@hotmail.com
#   Primary: CUST_1028
#   Duplicates: ['CUST_1176']
# Email: mia.wagner@gmail.com
#   Primary: CUST_1818
#   Duplicates: ['CUST_2035']
# Email: mia.wagner@hotmail.com
#   Primary: CUST_1682
#   Duplicates: ['CUST_1983', 'CUST_1360']
# Email: mia.wagner@outlook.com
#   Primary: CUST_1889
#   Duplicates: ['CUST_1258', 'CUST_1303']
# Email: mia.wagner@yahoo.com
#   Primary: CUST_1508
#   Duplicates: ['CUST_1115', 'CUST_1734']
# Email: mia.weber@hotmail.com
#   Primary: CUST_1013
#   Duplicates: ['CUST_1902']
# Email: noah.bakker@icloud.com
#   Primary: CUST_1714
#   Duplicates: ['CUST_1959']
# Email: noah.bakker@outlook.com
#   Primary: CUST_2108
#   Duplicates: ['CUST_1771']
# Email: noah.dejong@outlook.com
#   Primary: CUST_1851
#   Duplicates: ['CUST_1832']
# Email: noah.dejong@yahoo.com
#   Primary: CUST_1383
#   Duplicates: ['CUST_1732']
# Email: noah.desmet@gmail.com
#   Primary: CUST_1148
#   Duplicates: ['CUST_1238']
# Email: noah.desmet@icloud.com
#   Primary: CUST_1434
#   Duplicates: ['CUST_1039']
# Email: noah.desmet@yahoo.com
#   Primary: CUST_1109
#   Duplicates: ['CUST_1262', 'CUST_1044']
# Email: noah.devries@hotmail.com
#   Primary: CUST_1576
#   Duplicates: ['CUST_1446', 'CUST_1994']
# Email: noah.devries@icloud.com
#   Primary: CUST_1012
#   Duplicates: ['CUST_1760']
# Email: noah.jacobs@hotmail.com
#   Primary: CUST_2121
#   Duplicates: ['CUST_1436']
# Email: noah.jacobs@icloud.com
#   Primary: CUST_1976
#   Duplicates: ['CUST_1063', 'CUST_2213']
# Email: noah.jansen@outlook.com
#   Primary: CUST_1557
#   Duplicates: ['CUST_1579']
# Email: noah.janssens@gmail.com
#   Primary: CUST_1758
#   Duplicates: ['CUST_1409']
# Email: noah.maes@gmail.com
#   Primary: CUST_1845
#   Duplicates: ['CUST_1217']
# Email: noah.maes@hotmail.com
#   Primary: CUST_1458
#   Duplicates: ['CUST_2046']
# Email: noah.maes@yahoo.com
#   Primary: CUST_1212
#   Duplicates: ['CUST_1731']
# Email: noah.mertens@yahoo.com
#   Primary: CUST_1991
#   Duplicates: ['CUST_1490']
# Email: noah.peeters@icloud.com
#   Primary: CUST_2049
#   Duplicates: ['CUST_1019', 'CUST_1215']
# Email: noah.peeters@yahoo.com
#   Primary: CUST_2092
#   Duplicates: ['CUST_1707']
# Email: noah.vandenberg@icloud.com
#   Primary: CUST_1912
#   Duplicates: ['CUST_2212']
# Email: noah.visser@outlook.com
#   Primary: CUST_1121
#   Duplicates: ['CUST_1295', 'CUST_1450']
# Email: noah.visser@yahoo.com
#   Primary: CUST_2183
#   Duplicates: ['CUST_1745']
# Email: noah.willems@hotmail.com
#   Primary: CUST_1342
#   Duplicates: ['CUST_1926']
# Email: paul.fischer@gmail.com
#   Primary: CUST_1626
#   Duplicates: ['CUST_1652']
# Email: paul.meyer@gmail.com
#   Primary: CUST_1053
#   Duplicates: ['CUST_2141']
# Email: paul.schneider@yahoo.com
#   Primary: CUST_1944
#   Duplicates: ['CUST_1726']
# Email: paul.wagner@icloud.com
#   Primary: CUST_1667
#   Duplicates: ['CUST_1392']
# Email: sofie.desmet@hotmail.com
#   Primary: CUST_1305
#   Duplicates: ['CUST_2211']
# Email: sofie.desmet@icloud.com
#   Primary: CUST_1638
#   Duplicates: ['CUST_2032']
# Email: sofie.desmet@yahoo.com
#   Primary: CUST_1521
#   Duplicates: ['CUST_1129', 'CUST_1497']
# Email: sofie.jacobs@hotmail.com
#   Primary: CUST_1085
#   Duplicates: ['CUST_1676']
# Email: sofie.jacobs@yahoo.com
#   Primary: CUST_1627
#   Duplicates: ['CUST_1568']
# Email: sofie.maes@gmail.com
#   Primary: CUST_1059
#   Duplicates: ['CUST_1909']
# Email: sofie.maes@icloud.com
#   Primary: CUST_1778
#   Duplicates: ['CUST_1163', 'CUST_1151', 'CUST_1629']
# Email: sofie.mertens@yahoo.com
#   Primary: CUST_1610
#   Duplicates: ['CUST_1831']
# Email: sofie.peeters@outlook.com
#   Primary: CUST_1808
#   Duplicates: ['CUST_1323']
# Email: sofie.peeters@yahoo.com
#   Primary: CUST_1720
#   Duplicates: ['CUST_1570']
# Email: sofie.simon@gmail.com
#   Primary: CUST_1364
#   Duplicates: ['CUST_2209']
# Email: sophia.fischer@yahoo.com
#   Primary: CUST_1729
#   Duplicates: ['CUST_2052', 'CUST_1642']
# Email: sophia.meyer@icloud.com
#   Primary: CUST_1091
#   Duplicates: ['CUST_1654']
# Email: sophia.meyer@outlook.com
#   Primary: CUST_1969
#   Duplicates: ['CUST_1112']
# Email: sophia.müller@yahoo.com
#   Primary: CUST_1315
#   Duplicates: ['CUST_1358']
# Email: sophia.schneider@icloud.com
#   Primary: CUST_1065
#   Duplicates: ['CUST_1511']
# Email: sophia.wagner@icloud.com
#   Primary: CUST_2138
#   Duplicates: ['CUST_1201']
# Email: sophie.bakker@gmail.com
#   Primary: CUST_1846
#   Duplicates: ['CUST_1878']
# Email: sophie.bakker@icloud.com
#   Primary: CUST_1185
#   Duplicates: ['CUST_1657', 'CUST_1693']
# Email: sophie.dejong@yahoo.com
#   Primary: CUST_2165
#   Duplicates: ['CUST_1855']
# Email: sophie.devries@outlook.com
#   Primary: CUST_1985
#   Duplicates: ['CUST_2064']
# Email: sophie.devries@yahoo.com
#   Primary: CUST_1789
#   Duplicates: ['CUST_2077']
# Email: sophie.jansen@gmail.com
#   Primary: CUST_1786
#   Duplicates: ['CUST_1007']
# Email: sophie.jansen@outlook.com
#   Primary: CUST_2187
#   Duplicates: ['CUST_1764']
# Email: sophie.jansen@yahoo.com
#   Primary: CUST_1625
#   Duplicates: ['CUST_1029', 'CUST_1453']
# Email: sophie.vandenberg@gmail.com
#   Primary: CUST_2147
#   Duplicates: ['CUST_1949', 'CUST_1640']
# Email: sophie.vandenberg@outlook.com
#   Primary: CUST_1384
#   Duplicates: ['CUST_2004']
# Email: sophie.visser@yahoo.com
#   Primary: CUST_1798
#   Duplicates: ['CUST_1905']
# Email: thomas.desmet@gmail.com
#   Primary: CUST_2109
#   Duplicates: ['CUST_1903', 'CUST_2208']
# Email: thomas.desmet@yahoo.com
#   Primary: CUST_1911
#   Duplicates: ['CUST_1095']
# Email: thomas.jacobs@gmail.com
#   Primary: CUST_1687
#   Duplicates: ['CUST_1482', 'CUST_2163']
# Email: thomas.janssens@gmail.com
#   Primary: CUST_2154
#   Duplicates: ['CUST_1410', 'CUST_1874']
# Email: thomas.maes@yahoo.com
#   Primary: CUST_1864
#   Duplicates: ['CUST_2084']
# Email: thomas.mertens@yahoo.com
#   Primary: CUST_1359
#   Duplicates: ['CUST_1811']
# Email: thomas.peeters@gmail.com
#   Primary: CUST_1703
#   Duplicates: ['CUST_1111', 'CUST_1132']
# Email: thomas.peeters@outlook.com
#   Primary: CUST_1794
#   Duplicates: ['CUST_1735']
# Email: thomas.willems@gmail.com
#   Primary: CUST_1073
#   Duplicates: ['CUST_1996', 'CUST_2003']
#
# ✓ Removed 437 duplicate customers
# ✓ Kept 783 unique customers

# %%
#3 Third, I will handle null values

# Handle loyalty_status (21.6% NULL)
df_customers_clean['loyalty_status'] = df_customers_clean['loyalty_status'].fillna('Unclassified')

# Handle age (3.5% NULL) - Impute with median by country
df_customers_clean['age'] = df_customers_clean.groupby('country')['age'].transform(
    lambda x: x.fillna(x.median())
)

# If still NULL (edge case), use overall median
# df_customers_clean['age'] = df_customers_clean['age'].fillna(df_customers_clean['age'].median())

# Handle signup_date (4.1% NULL) - Flag as unknown
df_customers_clean['signup_date_missing'] = df_customers_clean['signup_date'].isna()
# Keep as NULL or impute with earliest date in dataset
# df_customers_clean['signup_date'] = df_customers_clean['signup_date'].fillna('2021-01-01')

# %%
df_customers_clean['loyalty_status'].head(30)
# Out:
# 0           Silver
# 1             Gold
# 2     Unclassified
# 3     Unclassified
# 8     Unclassified
# 9     Unclassified
# 10        Platinum
# 11    Unclassified
# 12          Silver
# 14            Gold
# 15    Unclassified
# 16        Platinum
# 20    Unclassified
# 21          Silver
# 24    Unclassified
# 25    Unclassified
# 27    Unclassified
# 30          Silver
# 32    Unclassified
# 35        Platinum
# 37          Silver
# 39        Platinum
# 40        Platinum
# 44            Gold
# 45        Platinum
# 46        Platinum
# 47        Platinum
# 50    Unclassified
# 51          Silver
# 52    Unclassified
# Name: loyalty_status, dtype: object

# %%
df_customers_clean['age'].head(30)
# Out:
# 0     55.0
# 1     70.0
# 2     65.0
# 3     34.0
# 8     52.0
# 9     33.0
# 10    68.0
# 11    27.0
# 12    67.0
# 14    69.0
# 15    31.0
# 16    49.0
# 20    66.0
# 21    54.0
# 24    40.0
# 25    64.0
# 27    70.0
# 30    53.0
# 32    60.0
# 35    32.0
# 37    39.0
# 39    44.0
# 40    28.0
# 44    58.0
# 45    55.0
# 46    45.0
# 47    25.0
# 50    54.0
# 51    68.0
# 52    38.0
# Name: age, dtype: float64

# %%
df_customers_clean[df_customers_clean['signup_date_missing']]
# Out:
#      customer_id first_name     last_name      country              city  \
# 220    CUST_1221      Marie        Dubois   Luxembourg  Esch-sur-Alzette
# 318    CUST_1319       Lars        Jacobs      Belgium             Ghent
# 356    CUST_1357       Noah       Mertens      Belgium            Bruges
# 413    CUST_1414      Lucas       Mertens      Belgium             Ghent
# 446    CUST_1447      Louis        Michel       France         Marseille
# 477    CUST_1478       Paul         Weber      Germany            Berlin
# 513    CUST_1514    Gabriel        Dubois       France              Nice
# 559    CUST_1560      Julia  van den Berg  Netherlands         Eindhoven
# 576    CUST_1577       Noah       Mertens   Luxembourg  Esch-sur-Alzette
# 658    CUST_1659      Chloé       Peeters   Luxembourg  Esch-sur-Alzette
# 672    CUST_1673      Sofie       Mertens      Belgium             Liège
# 923    CUST_1924      Sofie         Simon   Luxembourg   Luxembourg City
# 976    CUST_1977      Lucas       Bernard   Luxembourg  Esch-sur-Alzette
# 1019   CUST_2020     Sophie        Visser  Netherlands         Amsterdam
# 1028   CUST_2029      Julia      de Vries  Netherlands         The Hague
# 1082   CUST_2083     Louise         Simon       France              Nice
# 1095   CUST_2096     Thomas        Dubois   Luxembourg  Esch-sur-Alzette
# 1170   CUST_2171      Marie        Jacobs   Luxembourg  Esch-sur-Alzette
#
#                              email signup_date loyalty_status   age  \
# 220         marie.dubois@yahoo.com         NaN         Silver  52.0
# 318          lars.jacobs@gmail.com         NaN   Unclassified  25.0
# 356       noah.mertens@outlook.com         NaN   Unclassified  46.0
# 413       lucas.mertens@icloud.com         NaN   Unclassified  67.0
# 446       louis.michel@hotmail.com         NaN           Gold  40.0
# 477           paul.weber@yahoo.com         NaN           Gold  54.0
# 513       gabriel.dubois@gmail.com         NaN   Unclassified  29.0
# 559   julia.vandenberg@outlook.com         NaN   Unclassified  32.0
# 576         noah.mertens@gmail.com         NaN       Platinum  67.0
# 658      chloé.peeters@hotmail.com         NaN       Platinum  47.0
# 672        sofie.mertens@gmail.com         NaN   Unclassified  38.0
# 923          sofie.simon@yahoo.com         NaN       Platinum  39.0
# 976      lucas.bernard@outlook.com         NaN       Platinum  64.0
# 1019      sophie.visser@icloud.com         NaN   Unclassified  58.0
# 1028     julia.devries@outlook.com         NaN         Silver  56.0
# 1082      louise.simon@hotmail.com         NaN       Platinum  52.0
# 1095      thomas.dubois@icloud.com         NaN   Unclassified  58.0
# 1170      marie.jacobs@outlook.com         NaN   Unclassified  42.0
#
#                     email_original  signup_date_missing
# 220         marie.dubois@yahoo.com                 True
# 318          lars.jacobs@gmail.com                 True
# 356        noah.mertensoutlook.com                 True
# 413       lucas.mertens@icloud.com                 True
# 446       louis.michel@hotmail.com                 True
# 477           paul.weber@yahoo.com                 True
# 513       gabriel.dubois@gmail.com                 True
# 559   JULIA.VANDENBERG@OUTLOOK.COM                 True
# 576         NOAH.MERTENS@GMAIL.COM                 True
# 658      chloé.peeters@hotmail.com                 True
# 672        sofie.mertens@gmail.com                 True
# 923          SOFIE.SIMON@YAHOO.COM                 True
# 976      LUCAS.BERNARD@OUTLOOK.COM                 True
# 1019      sophie.visser@icloud.com                 True
# 1028     julia.devries@outlook.com                 True
# 1082      louise.simon@hotmail.com                 True
# 1095      thomas.dubois@icloud.com                 True
# 1170      marie.jacobs@outlook.com                 True

# %%
#4 Standardizing city and country columns just in case (there should be no problems there)

# Standardize country names (proper case)
df_customers_clean['country'] = df_customers_clean['country'].str.title()

# Standardize city names
df_customers_clean['city'] = df_customers_clean['city'].str.title()

# Final validation
print("\n✓ Customers Table Cleaned!")
print(f"Original rows: {len(df_customers)}")
print(f"Cleaned rows:  {len(df_customers_clean)}")
print(f"Rows removed:  {len(df_customers) - len(df_customers_clean)}")
# Out:
# ✓ Customers Table Cleaned!
# Original rows: 1220
# Cleaned rows:  783
# Rows removed:  437

# %%
# Save cleaned customers
df_customers_clean.to_csv('C:/Users/Eljan Mammadbayov/OneDrive/Рабочий стол/Python Practice/Euromart Claude/customers_cleaned.csv', index=False)
print("✓ Saved: C:/Users/Eljan Mammadbayov/OneDrive/Рабочий стол/Python Practice/Euromart Claude/customers_cleaned.csv")
# Out:
# ✓ Saved: C:/Users/Eljan Mammadbayov/OneDrive/Рабочий стол/Python Practice/Euromart Claude/customers_cleaned.csv
